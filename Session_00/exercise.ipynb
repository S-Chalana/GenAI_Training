# %% [markdown]
# # Module 1 - Exercise

# %%
print("Saruchi")
# Out:
# Saruchi

# %%
print(f"My batch is ('SAT/THUR')")
# Out:
# My batch is ('SAT/THUR')

# %%
print(f"My fav topic is ('How to create Agents')")
# Out:
# My fav topic is ('How to create Agents')

# %% [markdown]
# # Module 2 - Exercise
# # Create variables for student details and format a message using f-strings.

# %%
student_name = 'Saruchi Chalana'
student_ID = 2345
student_batch = 'Oct2025'
print(f"The student {student_name} with ID {student_ID} belongs to the {student_batch} batch")
# Out:
# The student Saruchi Chalana with ID 2345 belongs to the Oct2025 batch

# %% [markdown]
# # Slice a string to extract only part of it.

# %%
string_full = "Hello, welcome to the world of Python programming!"

# %%
print(string_full)
string_slice = string_full[7:14]
print(string_slice)
# Out:
# Hello, welcome to the world of Python programming!
# welcome
