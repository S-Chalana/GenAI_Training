# %% [markdown]
# ## Ask question through OpenAI

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
import time

# %%
load_dotenv(override=True)
api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key=api_key)

# %%
def ask_question_openai(prompt, max_retries=5):
            response = client.chat.completions.create(
                model="gpt-4o",
                messages=[
                    {"role": "system", "content": "You are a helpful assistant."},
                    {"role": "user", "content": prompt}
                ],
                max_tokens=100,
            )
            return response.choices[0].message.content

prompt = "are there any layoff planned for today?."
response = ask_question_openai(prompt)
print(response)
# Out:
# I'm sorry, but I don't have real-time internet access or the ability to provide current or live updates, including news about layoffs scheduled for today. To get the most up-to-date information, it is best to check reputable news sources or official company announcements.

# %% [markdown]
# ## Ask question through Ollama

# %%
import ollama

# %%
def ask_question_ollama(prompt):
    response = ollama.chat(
        model="llama3", 
         messages=[
            {"role": "system", "content":"You are a helpful assistant."},
            {"role": "user", "content": prompt}]
    )
    return response['message']['content']

response = ask_question_ollama("What is the capital of France?")
print(response)
# Out:
# The capital of France is Paris!

# %% [markdown]
# ##Local vs. OpenAI LLMs for Multimodal Data Extraction

# %% [markdown]
# ## Extract pdf through Local vs. OpenAI LLMs

# %%
import pdfplumber, docx, base64

client = OpenAI()

# %%
pdf_path = "data/Home_Insurance_Policy.pdf"
def extract_text_from_pdf(path):
    text = ""
    with pdfplumber.open(path) as pdf:
        for page in pdf.pages:
            t = page.extract_text()
            text += t + "/n"
    return text.strip()

pdf_text = extract_text_from_pdf(pdf_path)
pdf_text
# Out:
# 'Your home insurance policy\nJ18018_NHDHG6080_0517.indd 1 24/04/17 6:48 pm/nHOW TO GET HELP…\nClaims Contact Opening hours\nPlease have your policy number ready when you call\nHome claims (except Legal Services and Take a look at MAKING A CLAIM below then go\nHome Emergency). online at www.aviva.co.uk/make-a-claim or call\n0345 030 6945\nPlease always call if you need urgent help\n24 hours a day\nLegal Services claims. 0800 096 5850\nHome Emergency claims (including complaints about 0345 300 3346\nHome Emergency claims or cover terms and conditions)\nComplaints about a claim (except Home Emergency) 0345 030 6945\nHelplines\nPersonal Legal and Tax helpline 0800 096 5850\n(Advice is limited to the laws and practices of England and Wales, 24 hours a day\nScotland, Northern Ireland, the Channel Islands and the Isle of Man).\nCustomer services\nQuestions or changes to your policy or the 0345 030 7078 or make your changes online at\ninformation you’ve given us aviva.co.uk/mypolicy. 8am – 8pm Mon-Fri\nRequests for large print, audio or Braille 0345 030 7078 9am – 5pm Sat\npolicy documents if you have a disability.\n10am – 4pm Sun\nComplaints (other than about a claim). 0345 030 7078 alternatively write to us at Cruan Business Centre, and Bank holidays\nWesterhill Business Park, 123 Westerhill Road, Bishopbriggs G64 2QR\nTelephone call charges and recording\nCalls to 0800 numbers from UK landlines and mobiles are free. The costs of calls to 03 prefixed numbers are charged at national call rates\n(charges may vary depending on your network provider) and are usually included in inclusive minute plans from landlines and mobiles.\nFor our joint protection telephone calls may be recorded and/or monitored.\nWhat to do if you’re unhappy\nIf you have a complaint please see above for the contact numbers. Full details of the complaints procedure can be found in the ‘Important\nInformation’ document. 2\nJ18018_NHDHG6080_0517.indd 2 24/04/17 6:48 pm/nHOW TO GET HELP… MAKING A CLAIM\nIf you need to make a claim or have a query about something Getting ready to claim\nthat’s happened please see the contacts on the previous page.\nHaving the right information to hand when you’re telling us\nPlease always call us if you need urgent help, for example: about a claim will help us to get things moving quickly. Here’s\nwhat’s likely to be useful:\n● your home isn’t secure (eg damaged locks, doors or windows)\n● there is standing water in your home Your Home policy number (unless you’re logged on to\nMyAviva.)\n● a water leak is on-going or water is entering your home\nP hotos of damaged or lost property. For buildings\n● anyone is at risk of injury\ndamage it is helpful to have close up and distance shots to\n● your home can’t be lived in see the damage in detail as well as its location.\nOur personal claims managers offer help and advice around\nR eceipts, quotes or invoices, where appropriate.\nthe clock 365 days a year. We want your claim to be as stress-\nfree as possible. If the incident is covered we’ll take care of the E stimate of the size of the affected area where buildings\narrangements. You just have to pay the excess. or carpets are damaged. It can also help to tell us the size of\nthe affected rooms.\nOnce we have your claim details we’ll put wheels in motion\nand explain what will happen next. Some claims can be settled Photos and documents (word, pdf) can be uploaded when you\nimmediately on the first call but if it takes longer we’ll keep you tell us about a claim online.\ninformed about progress.\nPlease remember – in the same way that your car insurance doesn’t pay to repair your car if it rusts, this policy won’t cover wear and tear,\nageing or (except for optional Home Emergency cover) breakdowns.\nTelephone call charges and recording\nCalls to 0800 numbers from UK landlines and mobiles are free. The costs of calls to 03 prefixed numbers are charged at national call rates\n(charges may vary depending on your network provider) and are u ...

# %%
## the Ollama way
import ollama

prompt = f"""Extract key structured information:
Policy holder name
Policy number
Start and end date
Premium amount
Coverage summary
 from this pdf: \n\n {pdf_text}"""

response = ollama.chat(
    model = "llama3",
    messages = [{"role": "System", "content": "You are a helpful assistant"},
                {"role": "assistant", "content": "Provide this extracted information in a structured JSON"},
                {"role":"User", "content": prompt}
                ]
                     )

print(response['message'] ['content'])
# Out:
# Here is the extracted key structured information:
#
# **Policy Holder Name**: Not specified
#
# **Policy Details**
#
# * Policy Type: Home Insurance
# * Start Date: Not specified
# * End Date: Not specified
# * Sum Insured: Varies (contents and buildings)
# * Excess: Not specified
#
# **Covered Events**
#
# * Fire
# * Theft
# * Storms and floods
# * Malicious damage
# * Burst pipes
# * Subsidence
# * Earthquakes
#
# **Exclusions**
#
# * War
# * Terrorism
# * Radioactivity
# * Pollution or contamination (unless caused by a sudden and unexpected accident)
# * Deliberate or criminal acts
# * Events before the cover start date
#
# **Other Information**
#
# * Index Linking: Sum insured may be updated monthly to reflect rising costs
# * Joint Policyholders: More than one policyholder can be named on the policy, with each able to make claims and amend the policy
# * Cancellation: The policy may be cancelled due to non-payment of premium or fraud
# * Refunds: Refunds will be made for premiums paid if the policy is cancelled
#
# Please note that this information is based on a sample policy document and may not reflect the actual terms and conditions of your specific insurance policy. It's always best to consult your policy documents or contact your insurer directly for clarification on any questions you may have.

# %%
## The OpenAI way
import os
from dotenv import load_dotenv

load_dotenv(override=True, dotenv_path="../.env")
my_api_key = os.getenv("OPEN_AI_API_KEY")

# %%
from openai import OpenAI
my_client = OpenAI(api_key=my_api_key)
my_client

# %%
def ask_question_openai(pdf_text, max_retries=5): 
            prompt = f"Extract details from this pdf: \n\n {pdf_text}"
            response = my_client.chat.completions.create(
                model="gpt-5-nano",
                messages=[
                    {"role": "system", "content": "You are a helpful assistant."},
                    {"role": "assistant", "content": "Provide this extracted information in a structured JSON"},
                    {"role": "user", "content": prompt}
                ]           )
            return response.choices[0].message.content

response = ask_question_openai(pdf_text)
print(response)
# Out:
# {
#   "policyDetails": {
#     "title": "Your home insurance policy",
#     "documentCode": "J18018_NHDHG6080_0517.indd",
#     "versionDate": "24/04/2017",
#     "periodOfInsurance": "as shown on your schedule",
#     "issuer": "Aviva Insurance Limited"
#   },
#   "contactsAndSupport": {
#     "claimsContacts": {
#       "homeClaims": {
#         "number": "0345 030 6945",
#         "notes": "24 hours a day; online at www.aviva.co.uk/make-a-claim"
#       },
#       "legalServicesClaims": {
#         "number": "0800 096 5850"
#       },
#       "homeEmergencyClaims": {
#         "number": "0345 300 3346"
#       },
#       "claimsComplaints": {
#         "number": "0345 030 6945"
#       },
#       "helplines": [
#         {
#           "name": "Personal Legal and Tax helpline",
#           "number": "0800 096 5850",
#           "notes": "Advice limited to laws and practices of England & Wales, Scotland, Northern Ireland, Channel Islands and Isle of Man"
#         }
#       ],
#       "customerServices": {
#         "phone": "0345 030 7078",
#         "hours": "8am – 8pm Mon-Fri; 9am – 5pm Sat; 10am – 4pm Sun; Bank holidays"
#       },
#       "largePrintPolicyDocuments": {
#         "phone": "0345 030 7078",
#         "hours": "9am – 5pm Sat; 10am – 4pm Sun"
#       },
#       "addressForComplaints": "Cruan Business Centre, Westerhill Business Park, 123 Westerhill Road, Bishopbriggs G64 2QR"
#     },
#     "telephoneCharges": {
#       "notes": "Calls to 0800 numbers from UK landlines and mobiles are free. 03 prefixed numbers are charged at national call rates. Calls may be recorded and/or monitored."
#     },
#     "unhappyProcess": {
#       "complaintsProcedureDocument": "Important Information",
#       "contactNumbers": ["0345 030 6945", "0345 030 7078"]
#     }
#   },
#   "claimsProcessInfo": {
#     "gettingReadyToClaim": [
#       "Your Home policy number (unless you’re logged on to MyAviva)",
#       "Photos of damaged or lost property",
#       "Receipts, quotes or invoices where appropriate",
#       "Estimate of the size of the affected area (for buildings or carpets)"
#     ],
#     "urgentHelpExamples": [
#       "Your home isn’t secure (eg damaged locks, doors or windows)",
#       "Water is standing in your home or ongoing leaks",
#       "Anyone is at risk of injury"
#     ],
#     "progressNotes": "Our personal claims managers offer help and advice around the clock, and we’ll keep you informed about progress. If the incident is covered we’ll take care of the arrangements; you pay the excess if applicable.",
#     "onlineClaim": {
#       "url": "www.aviva.co.uk/make-a-claim"
#     },
#     "uploadOption": "Photos and documents (word, pdf) can be uploaded when you tell us about a claim online"
#   },
#   "definitions": {
#     "AccidentalDamage": "Damage caused suddenly and unexpectedly by an outside force.",
#     "BritishIsles": "The United Kingdom, Republic of Ireland, the Channel Islands and the Isle of Man.",
#     "Excess": "The amount you will have to pay towards each separate claim.",
#     "Home": "The home, its outbuildings (including garages), at the address shown on your schedule.",
#     "Contents": "Household items and personal belongings (including personal money, valuables and home office equipment) up to the limits shown on your schedule.",
#     "DomesticEmployee": "A person directly employed by you, solely to carry out domestic duties in your home and/or its garden.",
#     "SumInsured": "The maximum amount the policy will pay for losses under each section, as shown on your schedule.",
#     "Unoccupied": "Not lived in by you or anyone who has your permission; or not containing enough furniture for normal living purposes.",
#     "Valuables": "Stamp, coin or medal collections, pictures, other works of art, items of gold, silver or any other precious metal, jewellery, watches and furs.",
#     "PeriodOfInsurance": "The period of time covered by the policy, as shown on your schedule (or until cancelled)."
#   },
#   "sections": {
#     "BUILDINGS": {
#       "overview": "The Buildings section covers loss or damage to the buildings from listed causes.",
#       "covers": [
#         "Fire, explosion, lightning, earthquake or smoke",
#         "Storm or Flood",
#         "Riot, civil unrest, strikes, or labour/political disturbances",
#         "Malicious people or vandals (subject to exclusions)",
#         "Damage from being hit by aircraft, other flying objects, vehicles or animals",
#         "Water escaping from water tanks, pipes, equipment or fixed heating systems",
#         "Water freezing in tanks, equipment or pipes",
#         "Heating fuel leaking from a fixed heating system",
#         "Theft or attempted theft",
#         "Falling radio or television aerials, satellite dishes, and their fittings",
#         "Subsidence, heave or landslip",
#         "Replacement locks",
#         "Loss of rent and the cost of alternative accommodation",
#         "Emergency access",
#         "Tracing and accessing leaks",
#         "Selling your home"
#       ],
#       "exclusionsSummary": [
#         "Damage after the home has been left unoccupied for the period shown on schedule",
#         "Damage from riverbank or coastal erosion",
#         "Damage to solid floors caused by infill materials settling, swelling or shrinking",
#         "Damage caused by faulty or unsuitable materials, design or workmanship"
#       ]
#     },
#     "ACCIDENTAL_DAMAGE_TO_BUILDINGS": {
#       "overview": "Covers accidental damage to buildings not covered by the general Buildings section.",
#       "covers": [
#         "Damage to cables, pipes, septic tanks and drain inspection covers you are legally responsible for",
#         "Fixed glass and sanitary fittings installed at the home"
#       ],
#       "exclusions": [
#         "Damage due to fault or limit of design, manufacture, construction or installation",
#         "Damage to items described as excluded in Building section"
#       ]
#     },
#     "CONTENTS": {
#       "overview": "Covers contents in the home and some listed items when shown on schedule.",
#       "covers": [
#         "Loss or damage from Fire, explosion, lightning, earthquake or smoke",
#         "Storm or flood",
#         "Riot, civil unrest, malicious damage, or theft (subject to occupancy-related exclusions)",
#         "Water escaping from tanks, pipes, equipment or fixed heating systems",
#         "Heating fuel leaking from fixed heating system",
#         "Theft or attempted theft",
#         "Falling aerials and masts",
#         "Subsidence, heave or landslip",
#         "Contents temporarily removed from the home",
#         "Contents in the garden"
#       ],
#       "exclusionsSummary": [
#         "More than the schedule limit for contents in garages/outbuildings",
#         "Theft by deception or by paying guests/tenants"
#       ]
#     },
#     "CONTENTS_IN_THE_GARDEN": {
#       "overview": "Covers contents loss or damage in the garden within the home’s boundaries.",
#       "exclusions": [
#         "Damage after home left unoccupied",
#         "Theft unless contents are secured",
#         "Loss or damage not within the home’s boundaries"
#       ]
#     },
#     "GARDEN_RE-LANDSCAPING": {
#       "overview": "Re-landscaping costs if the garden is damaged by insured perils.",
#       "covers": [
#         "Replacement of any damaged plants, trees or shrubs",
#         "Re-landscaping costs up to limits shown on schedule"
#       ],
#       "exclusions": [
#         "Theft or malicious damage by you or paying guests/tenants",
#         "Smoke damage from gradual cause"
#       ]
#     },
#     "REPLACEMENT_LOCKS": {
#       "overview": "Costs to replace external door locks or alarm system locks if lost or stolen."
#     },
#     "FOOD_IN_FREEZERS": {
#       "overview": "Loss or damage to food stored in a freezer due to temperature change or contamination.",
#       "exclusions": [
#         "Deliberate act, or power-related theft by supplier"
#       ]
#     },
#     "DOMESTIC_HEATING_FUEL": {
#       "overview": "Accidental leakage of domestic heating fuel or metered water."
#     },
#     "FATAL_INJURY_BENEFIT": {
#       "overview": "Pay out if you die as a direct result of injury caused in the home by fire, explosion, lightning or intruders (within 3 months)."
#     },
#     "PLEDGE_AND_REMOVALS": {
#       "overview": "Household removals cover for contents damaged or stolen during professional removal within the British Isles."
#     },
#     "OCCUPIERs_LIABILITY": {
#       "overview": "Legal liability to pay damages for accidental bodily injury or illness, accidental loss of or damage to property arising from occupancy of the home or its land."
#     },
#     "TENANTs_LIABILITY": {
#       "overview": "Tenant liability cover for damage to landlord’s property and fixtures, plus accidental damage to fixed glass and fittings."
#     }
#   },
#   "CONTENTS_SECTION_EXCLUSIONS": {
#     "general": [
#       "Excesses shown on schedule (except Fatal Injury Benefit, Occupier’s, Personal and Employer’s liability, and Emergency access)",
#       "Property insured by another policy",
#       "Documents (except personal money, passports, title deeds as stated)",
#       "Motorised vehicles and watercraft and their parts",
#       "Animals or living creatures",
#       "Items used for business or professional purposes (except home office equipment)"
#     ],
#     "specific": [
#       "Theft from unattended vehicle (restricted by limit)",
#       "Damage by wear and tear, gradual processes, weather conditions",
#       "Loss or damage covered by another policy"
#     ]
#   },
#   "PERSONAL_BELONGINGS": {
#     "overview": "Covers personal items shown on schedule anywhere in the world.",
#     "covers": [
#       "Loss or damage to personal belongings in the home and worldwide when shown on schedule",
#       "Personal money, credit and debit cards (subject to conditions)"
#     ],
#     "exclusionsSummary": [
#       "Items not shown on schedule",
#       "Sports equipment used in play or sport while in use",
#       "Business goods and equipment",
#       "Animals, living creatures"
#     ],
#     "PEDAL_CYCLES": {
#       "overview": "Covers pedal cycles (including electrically assisted) and parts/accessories when shown on schedule.",
#       "conditions": [
#         "In immediate custody and control",
#         "Securely locked to an immovable object or kept in a locked building"
#       ],
#       "exclusions": [
#         "Theft from an unattended vehicle not meeting criteria",
#         "Theft if not securely locked or accessible to public"
#       ]
#     }
#   },
#   "GENERAL_CONDITIONS": {
#     "overview": "Apply to all sections of the policy.",
#     "dutiesBeforeClaim": [
#       "Provide complete and accurate information when applying, renewing, or making changes",
#       "Inform us of changes (e.g., moving, alterations, new occupants)"
#     ],
#     "dutyToPreventLoss": "Take reasonable precautions to prevent accidents, loss or damage",
#     "fraud": "If a claim is dishonest or exaggerated, no benefit and possible cancellation",
#     "otherInsurance": "If another policy covers the same claim, this policy may not pay in excess of its share",
#     "cancellation": "You can cancel; refunds and cancellation fees apply; 7 days’ notice in some cases",
#     "indexLinking": "Sums insured may be adjusted monthly with index changes; not reduced if index falls",
#     "jointPolicyholders": "Any policyholder can amend or claim; removal requires authority or agreement",
#     "dutyKeeptotheConditions": "You must comply with policy terms to be covered"
#   },
#   "GENERAL_EXCLUSIONS": {
#     "overview": [
#       "War",
#       "Terrorism",
#       "Radioactivity",
#       "Pollution or Contamination (except sudden accidents or specific oil leaks)",
#       "Deliberate or Criminal Acts",
#       "Pre-cover events (claims for events before the cover start date)"
#     ],
#     "notes": "These exclusions apply to all covers in the policy booklet."
#   },
#   "notes": {
#     "disclaimer": "This extraction reflects the provided text which appears to be OCR’d and may contain typographical artifacts. Always refer to the official policy booklet for authoritative terms, limits, and conditions."
#   }
# }
