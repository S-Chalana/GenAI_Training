# %% [markdown]
# # MCP Server & Client Implementation Using Fastmcp
#
# ---
# ## Architecture
#
# LLM Host (MCP Client)  <—— JSON-RPC ——>  fastmcp Server  <——> CSV Dataset
#
#
# We'll:
# 1. Launch a server exposing two tools (`summarize`, `query`).
# 2. Use an MCP Client to discover and call those tools.
# 3. Simulate a host (agent) deciding which tool to call.
# ---
# ## Start the MCP Server
#
# In a separate terminal, run:
# ```bash
# python mcp_server_fastmcp.py
# ```
# This starts an MCP-compliant server exposing `summarize` and `query` tools.
#
# ---

# %% [markdown]
# ### 1. Install dependencies

# %%
# %pip install fastmcp pandas langchain openai uvicorn --upgrade --no-cache-dir
# Out:
# Requirement already satisfied: fastmcp in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (2.14.0)
# Requirement already satisfied: pandas in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: langchain in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (1.1.0)
# Collecting langchain
#   Downloading langchain-1.1.3-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: openai in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (2.6.1)
# Collecting openai
#   Downloading openai-2.11.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: uvicorn in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (0.38.0)
# Requirement already satisfied: authlib>=1.6.5 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from fastmcp) (1.6.5)
# Requirement already satisfied: cyclopts>=4.0.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from fastmcp) (4.3.0)
# Requirement already satisfied: exceptiongroup>=1.2.2 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from fastmcp) (1.3.1)
# Requirement already satisfied: httpx>=0.28.1 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from fastmcp) (0.28.1)
# Requirement already satisfied: jsonschema-path>=0.3.4 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from fastmcp) (0.3.4)
# Requirement already satisfied: mcp>=1.23.1 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from fastmcp) (1.23.3)
# Requirement already satisfied: openapi-pydantic>=0.5.1 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from fastmcp) (0.5.1)
# Requirement already satisfied: platformdirs>=4.0.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from fastmcp) (4.5.0)
# Requirement already satisfied: py-key-value-aio<0.4.0,>=0.3.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (0.3.0)
# Requirement already satisfied: pydantic>=2.11.7 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from pydantic[email]>=2.11.7->fastmcp) (2.12.3)
# Requirement already satisfied: pydocket>=0.15.2 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from fastmcp) (0.15.4)
# Requirement already satisfied: pyperclip>=1.9.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from fastmcp) (1.11.0)
# Requirement already satisfied: python-dotenv>=1.1.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from fastmcp) (1.2.1)
# Requirement already satisfied: rich>=13.9.4 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from fastmcp) (14.2.0)
# Requirement already satisfied: websockets>=15.0.1 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from fastmcp) (15.0.1)
# Requirement already satisfied: py-key-value-shared==0.3.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from py-key-value-aio<0.4.0,>=0.3.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (0.3.0)
# Requirement already satisfied: beartype>=0.20.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from py-key-value-aio<0.4.0,>=0.3.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (0.22.8)
# Requirement already satisfied: typing-extensions>=4.15.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from py-key-value-shared==0.3.0->py-key-value-aio<0.4.0,>=0.3.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (4.15.0)
# Requirement already satisfied: diskcache>=5.0.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (5.6.3)
# Requirement already satisfied: pathvalidate>=3.3.1 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (3.3.1)
# Requirement already satisfied: keyring>=25.6.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (25.7.0)
# Requirement already satisfied: cachetools>=5.0.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (6.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from pandas) (2025.2)
# Collecting langchain-core<2.0.0,>=1.1.2 (from langchain)
#   Downloading langchain_core-1.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from langchain) (1.0.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain) (0.4.53)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.2->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.12)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.2->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.2->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.2->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from httpx>=0.28.1->fastmcp) (4.11.0)
# Requirement already satisfied: certifi in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from httpx>=0.28.1->fastmcp) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from httpx>=0.28.1->fastmcp) (1.0.9)
# Requirement already satisfied: idna in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from httpx>=0.28.1->fastmcp) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.28.1->fastmcp) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from pydantic>=2.11.7->pydantic[email]>=2.11.7->fastmcp) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from pydantic>=2.11.7->pydantic[email]>=2.11.7->fastmcp) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from pydantic>=2.11.7->pydantic[email]>=2.11.7->fastmcp) (0.4.2)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from openai) (0.11.1)
# Requirement already satisfied: sniffio in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: click>=7.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from uvicorn) (8.3.1)
# Requirement already satisfied: cryptography in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from authlib>=1.6.5->fastmcp) (46.0.3)
# Requirement already satisfied: colorama in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Requirement already satisfied: attrs>=23.1.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from cyclopts>=4.0.0->fastmcp) (25.4.0)
# Requirement already satisfied: docstring-parser<4.0,>=0.15 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from cyclopts>=4.0.0->fastmcp) (0.17.0)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from cyclopts>=4.0.0->fastmcp) (1.3.2)
# Requirement already satisfied: docutils in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=4.0.0->fastmcp) (0.22.3)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from jsonschema-path>=0.3.4->fastmcp) (0.4.4)
# Requirement already satisfied: referencing<0.37.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from jsonschema-path>=0.3.4->fastmcp) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from referencing<0.37.0->jsonschema-path>=0.3.4->fastmcp) (0.30.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.2->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.2->langchain) (2.3.0)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (0.2.3)
# Requirement already satisfied: jaraco.classes in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (3.4.0)
# Requirement already satisfied: jaraco.functools in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (4.3.0)
# Requirement already satisfied: jaraco.context in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (6.0.1)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from mcp>=1.23.1->fastmcp) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from mcp>=1.23.1->fastmcp) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from mcp>=1.23.1->fastmcp) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.23.1->fastmcp) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from mcp>=1.23.1->fastmcp) (0.0.20)
# Requirement already satisfied: pywin32>=310 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from mcp>=1.23.1->fastmcp) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from mcp>=1.23.1->fastmcp) (3.0.3)
# Requirement already satisfied: starlette>=0.27 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from mcp>=1.23.1->fastmcp) (0.50.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.23.1->fastmcp) (2025.9.1)
# Requirement already satisfied: email-validator>=2.0.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from pydantic[email]>=2.11.7->fastmcp) (2.3.0)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp) (2.8.0)
# Requirement already satisfied: cloudpickle>=3.1.1 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from pydocket>=0.15.2->fastmcp) (3.1.2)
# Requirement already satisfied: fakeredis>=2.32.1 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from fakeredis[lua]>=2.32.1->pydocket>=0.15.2->fastmcp) (2.32.1)
# Requirement already satisfied: opentelemetry-api>=1.30.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from pydocket>=0.15.2->fastmcp) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-prometheus>=0.51b0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from pydocket>=0.15.2->fastmcp) (0.60b1)
# Requirement already satisfied: prometheus-client>=0.21.1 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from pydocket>=0.15.2->fastmcp) (0.23.1)
# Requirement already satisfied: python-json-logger>=2.0.7 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from pydocket>=0.15.2->fastmcp) (4.0.0)
# Requirement already satisfied: redis>=5 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from pydocket>=0.15.2->fastmcp) (7.1.0)
# Requirement already satisfied: typer>=0.15.1 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from pydocket>=0.15.2->fastmcp) (0.20.0)
# Requirement already satisfied: sortedcontainers>=2 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from fakeredis>=2.32.1->fakeredis[lua]>=2.32.1->pydocket>=0.15.2->fastmcp) (2.4.0)
# Requirement already satisfied: lupa>=2.1 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from fakeredis[lua]>=2.32.1->pydocket>=0.15.2->fastmcp) (2.6)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from opentelemetry-api>=1.30.0->pydocket>=0.15.2->fastmcp) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.30.0->pydocket>=0.15.2->fastmcp) (3.23.0)
# Requirement already satisfied: opentelemetry-sdk~=1.39.1 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from opentelemetry-exporter-prometheus>=0.51b0->pydocket>=0.15.2->fastmcp) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from opentelemetry-sdk~=1.39.1->opentelemetry-exporter-prometheus>=0.51b0->pydocket>=0.15.2->fastmcp) (0.60b1)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from cryptography->authlib>=1.6.5->fastmcp) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from cffi>=2.0.0->cryptography->authlib>=1.6.5->fastmcp) (2.23)
# Requirement already satisfied: six>=1.5 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from rich>=13.9.4->fastmcp) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from rich>=13.9.4->fastmcp) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->fastmcp) (0.1.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from typer>=0.15.1->pydocket>=0.15.2->fastmcp) (1.5.4)
# Requirement already satisfied: more-itertools in c:\users\schal\documents\saruchi\gen_ai_training\.venv\lib\site-packages (from jaraco.classes->keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (10.8.0)
# Downloading langchain-1.1.3-py3-none-any.whl (102 kB)
# Downloading langchain_core-1.1.3-py3-none-any.whl (475 kB)
# Downloading openai-2.11.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 48.4 MB/s  0:00:00
# Installing collected packages: openai, langchain-core, langchain
#
#   Attempting uninstall: openai
#
#     Found existing installation: openai 2.6.1
#
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#     Uninstalling openai-2.6.1:
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#       Successfully uninstalled openai-2.6.1
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#    ---------------------------------------- 0/3 [openai]
#   Attempting uninstall: langchain-core
#    ---------------------------------------- 0/3 [openai]
#     Found existing installation: langchain-core 1.1.0
#    ---------------------------------------- 0/3 [openai]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#     Uninstalling langchain-core-1.1.0:
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#       Successfully uninstalled langchain-core-1.1.0
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#   Attempting uninstall: langchain
#    ------------- -------------------------- 1/3 [langchain-core]
#     Found existing installation: langchain 1.1.0
#    ------------- -------------------------- 1/3 [langchain-core]
#    -------------------------- ------------- 2/3 [langchain]
#     Uninstalling langchain-1.1.0:
#    -------------------------- ------------- 2/3 [langchain]
#       Successfully uninstalled langchain-1.1.0
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    ---------------------------------------- 3/3 [langchain]
#
# Successfully installed langchain-1.1.3 langchain-core-1.1.3 openai-2.11.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Connect via MCP Client
#
# Once the server is running, connect using the MCP client to list tools and invoke them.

# %%
from fastmcp import Client
from fastmcp.client import PythonStdioTransport
import asyncio

async def main():
    # Create a client using the PythonStdioTransport
    # Create a loop to run the client

    transport = PythonStdioTransport("mcp_server_fastmcp.py")
    # client = Client(transport)
    async with Client(transport) as client:
        tools = await client.list_tools()
        print("Tools:", [t.name for t in tools])

await main()
# Out:
# ---------------------------------------------------------------------------
# ExceptionGroup                            Traceback (most recent call last)
# File c:\Users\schal\Documents\Saruchi\Gen_AI_Training\.venv\Lib\site-packages\exceptiongroup\_catch.py:63, in _Catcher.handle_exception(self, exc)
#      62 try:
# ---> 63     raise matched
#      64 except BaseExceptionGroup:
#
# ExceptionGroup:  (1 sub-exception)
#
# During handling of the above exception, another exception occurred:
#
# UnsupportedOperation                      Traceback (most recent call last)
# File c:\Users\schal\Documents\Saruchi\Gen_AI_Training\.venv\Lib\site-packages\fastmcp\client\client.py:582, in Client._session_runner(self)
#     581 async with AsyncExitStack() as stack:
# --> 582     await stack.enter_async_context(self._context_manager())
#     583     # Session/context is now ready
#
# File C:\Python313\Lib\contextlib.py:668, in AsyncExitStack.enter_async_context(self, cm)
#     665     raise TypeError(f"'{cls.__module__}.{cls.__qualname__}' object does "
#     666                     f"not support the asynchronous context manager protocol"
#     667                    ) from None
# --> 668 result = await _enter(cm)
#     669 self._push_async_cm_exit(cm, _exit)
#
# File C:\Python313\Lib\contextlib.py:214, in _AsyncGeneratorContextManager.__aenter__(self)
#     213 try:
# --> 214     return await anext(self.gen)
#     215 except StopAsyncIteration:
#
# File c:\Users\schal\Documents\Saruchi\Gen_AI_Training\.venv\Lib\site-packages\exceptiongroup\_catch.py:65, in _Catcher.handle_exception(self, exc)
#      64     except BaseExceptionGroup:
# ---> 65         result = handler(matched)
#      66 except BaseExceptionGroup as new_exc:
#
# File c:\Users\schal\Documents\Saruchi\Gen_AI_Training\.venv\Lib\site-packages\fastmcp\utilities\exceptions.py:29, in _exception_handler(group)
#      23     raise McpError(
#      24         error=mcp.types.ErrorData(
#      25             code=httpx.codes.REQUEST_TIMEOUT,
#      26             message="Timed out while waiting for response.",
#      27         )
#      28     )
# ---> 29 raise leaf
#
# File c:\Users\schal\Documents\Saruchi\Gen_AI_Training\.venv\Lib\site-packages\fastmcp\client\client.py:396, in Client._context_manager(self)
#     395 with catch(get_catch_handlers()):
# --> 396     async with self.transport.connect_session(
#     397         **self._session_kwargs
#     398     ) as session:
#     399         self._session_state.session = session
#
# File C:\Python313\Lib\contextlib.py:214, in _AsyncGeneratorContextManager.__aenter__(self)
#     213 try:
# --> 214     return await anext(self.gen)
#     215 except StopAsyncIteration:
#
# File c:\Users\schal\Documents\Saruchi\Gen_AI_Training\.venv\Lib\site-packages\fastmcp\client\transports.py:370, in StdioTransport.connect_session(self, **session_kwargs)
#     369 try:
# --> 370     await self.connect(**session_kwargs)
#     371     yield cast(ClientSession, self._session)
#
# File c:\Users\schal\Documents\Saruchi\Gen_AI_Training\.venv\Lib\site-packages\fastmcp\client\transports.py:409, in StdioTransport.connect(self, **session_kwargs)
#     408     if exception is not None:
# --> 409         raise exception
#     411 self._session = await session_future
#
# File c:\Users\schal\Documents\Saruchi\Gen_AI_Training\.venv\Lib\site-packages\fastmcp\client\transports.py:475, in _stdio_transport_connect_task(command, args, env, cwd, log_file, session_kwargs, ready_event, stop_event, session_future)
#     473     log_file_handle = log_file
# --> 475 transport = await stack.enter_async_context(
#     476     stdio_client(server_params, errlog=log_file_handle)
#     477 )
#     478 read_stream, write_stream = transport
#
# File C:\Python313\Lib\contextlib.py:668, in AsyncExitStack.enter_async_context(self, cm)
#     665     raise TypeError(f"'{cls.__module__}.{cls.__qualname__}' object does "
#     666                     f"not support the asynchronous context manager protocol"
#     667                    ) from None
# --> 668 result = await _enter(cm)
#     669 self._push_async_cm_exit(cm, _exit)
#
# File C:\Python313\Lib\contextlib.py:214, in _AsyncGeneratorContextManager.__aenter__(self)
#     213 try:
# --> 214     return await anext(self.gen)
#     215 except StopAsyncIteration:
#
# File c:\Users\schal\Documents\Saruchi\Gen_AI_Training\.venv\Lib\site-packages\mcp\client\stdio\__init__.py:124, in stdio_client(server, errlog)
#     123     # Open process with stderr piped for capture
# --> 124     process = await _create_platform_compatible_process(
#     125         command=command,
#     126         args=server.args,
#     127         env=({**get_default_environment(), **server.env} if server.env is not None else get_default_environment()),
#     128         errlog=errlog,
#     129         cwd=server.cwd,
#     130     )
#     131 except OSError:
#     132     # Clean up streams if process creation fails
#
# File c:\Users\schal\Documents\Saruchi\Gen_AI_Training\.venv\Lib\site-packages\mcp\client\stdio\__init__.py:249, in _create_platform_compatible_process(command, args, env, errlog, cwd)
#     248 if sys.platform == "win32":  # pragma: no cover
# --> 249     process = await create_windows_process(command, args, env, errlog, cwd)
#     250 else:
#
# File c:\Users\schal\Documents\Saruchi\Gen_AI_Training\.venv\Lib\site-packages\mcp\os\win32\utilities.py:181, in create_windows_process(command, args, env, errlog, cwd)
#     179 except NotImplementedError:
#     180     # If Windows doesn't support async subprocess creation, use fallback
# --> 181     process = await _create_windows_fallback_process(command, args, env, errlog, cwd)
#     182 except Exception:
#     183     # Try again without creation flags
#
# File c:\Users\schal\Documents\Saruchi\Gen_AI_Training\.venv\Lib\site-packages\mcp\os\win32\utilities.py:221, in _create_windows_fallback_process(command, args, env, errlog, cwd)
#     219 except Exception:
#     220     # If creationflags failed, fallback without them
# --> 221     popen_obj = subprocess.Popen(
#     222         [command, *args],
#     223         stdin=subprocess.PIPE,
#     224         stdout=subprocess.PIPE,
#     225         stderr=errlog,
#     226         env=env,
#     227         cwd=cwd,
#     228         bufsize=0,
#     229     )
#     230 return FallbackProcess(popen_obj)
#
# File C:\Python313\Lib\subprocess.py:1005, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#     988 # Input and output objects. The general principle is like
#     989 # this:
#     990 #
#    (...)   1000 # are -1 when not using PIPEs. The child objects are -1
#    1001 # when not redirecting.
#    1003 (p2cread, p2cwrite,
#    1004  c2pread, c2pwrite,
# -> 1005  errread, errwrite) = self._get_handles(stdin, stdout, stderr)
#    1007 # From here on, raising exceptions may cause file descriptor leakage
#    1008
#    1009 # We wrap OS handles *before* launching the child, otherwise a
#    1010 # quickly terminating child could make our fds unwrappable
#    1011 # (see #8458).
#
# File C:\Python313\Lib\subprocess.py:1422, in Popen._get_handles(self, stdin, stdout, stderr)
#    1420 else:
#    1421     # Assuming file-like object
# -> 1422     errwrite = msvcrt.get_osfhandle(stderr.fileno())
#    1423 errwrite = self._make_inheritable(errwrite)
#
# File c:\Users\schal\Documents\Saruchi\Gen_AI_Training\.venv\Lib\site-packages\ipykernel\iostream.py:372, in OutStream.fileno(self)
#     371 msg = "fileno"
# --> 372 raise io.UnsupportedOperation(msg)
#
# UnsupportedOperation: fileno
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 15
#      12         tools = await client.list_tools()
#      13         print("Tools:", [t.name for t in tools])
# ---> 15 await main()
#
# Cell In[2], line 11, in main()
#       9 transport = PythonStdioTransport("mcp_server_fastmcp.py")
#      10 # client = Client(transport)
# ---> 11 async with Client(transport) as client:
#      12     tools = await client.list_tools()
#      13     print("Tools:", [t.name for t in tools])
#
# File c:\Users\schal\Documents\Saruchi\Gen_AI_Training\.venv\Lib\site-packages\fastmcp\client\client.py:470, in Client.__aenter__(self)
#     469 async def __aenter__(self):
# --> 470     return await self._connect()
#
# File c:\Users\schal\Documents\Saruchi\Gen_AI_Training\.venv\Lib\site-packages\fastmcp\client\client.py:520, in Client._connect(self)
#     518             if isinstance(exception, httpx.HTTPStatusError | McpError):
#     519                 raise exception
# --> 520             raise RuntimeError(
#     521                 f"Client failed to connect: {exception}"
#     522             ) from exception
#     524     self._session_state.nesting_counter += 1
#     526 return self
#
# RuntimeError: Client failed to connect: fileno

# %% [markdown]
# ## Simulate a Simple Host Agent
# Let's simulate a rule-based 'AI agent' that decides whether to use `summarize` or `query` based on user text.

# %%
def decide_tool(text: str):
    text = text.lower()
    if "summarize" in text or "overview" in text:
        return "summarize", {}
    if "west" in text:
        return "query", {"expr": "region == 'West' and sales > 1500"}
    return "summarize", {}

async def run_agent(user_input, client):
    tool, params = decide_tool(user_input) #"summarize", {}
    #tool = "summarize"
    #params = {}
    print(f"Agent decided to use '{tool}'")

    # API for fastmcp 2.12.5
    result = await client.call_tool(tool, params)
    # result = await client.call_tool("query", params)

    print("Result:", result, "\n")

# %%
# create a connection to your MCP server
transport = PythonStdioTransport("mcp_server_fastmcp.py")

async with Client(transport) as client:
    await run_agent("Give me a summary of the dataset", client)
# Out:
# Agent decided to use 'summarize'
# Result: CallToolResult(content=[TextContent(type='text', text='{"rows":10,"columns":["order_id","region","sales","quarter","rep"],"numeric_stats":{"order_id":{"count":10.0,"unique":"","top":"","freq":"","mean":105.5,"std":3.0276503540974917,"min":101.0,"25%":103.25,"50%":105.5,"75%":107.75,"max":110.0},"region":{"count":10,"unique":4,"top":"West","freq":4,"mean":"","std":"","min":"","25%":"","50%":"","75%":"","max":""},"sales":{"count":10.0,"unique":"","top":"","freq":"","mean":1235.0,"std":536.4751210965477,"min":600.0,"25%":825.0,"50%":1175.0,"75%":1450.0,"max":2200.0},"quarter":{"count":10,"unique":4,"top":"Q1","freq":3,"mean":"","std":"","min":"","25%":"","50%":"","75%":"","max":""},"rep":{"count":10,"unique":10,"top":"Alex","freq":1,"mean":"","std":"","min":"","25%":"","50%":"","75%":"","max":""}}}', annotations=None, meta=None)], structured_content={'rows': 10, 'columns': ['order_id', 'region', 'sales', 'quarter', 'rep'], 'numeric_stats': {'order_id': {'count': 10.0, 'unique': '', 'top': '', 'freq': '', 'mean': 105.5, 'std': 3.0276503540974917, 'min': 101.0, '25%': 103.25, '50%': 105.5, '75%': 107.75, 'max': 110.0}, 'region': {'count': 10, 'unique': 4, 'top': 'West', 'freq': 4, 'mean': '', 'std': '', 'min': '', '25%': '', '50%': '', '75%': '', 'max': ''}, 'sales': {'count': 10.0, 'unique': '', 'top': '', 'freq': '', 'mean': 1235.0, 'std': 536.4751210965477, 'min': 600.0, '25%': 825.0, '50%': 1175.0, '75%': 1450.0, 'max': 2200.0}, 'quarter': {'count': 10, 'unique': 4, 'top': 'Q1', 'freq': 3, 'mean': '', 'std': '', 'min': '', '25%': '', '50%': '', '75%': '', 'max': ''}, 'rep': {'count': 10, 'unique': 10, 'top': 'Alex', 'freq': 1, 'mean': '', 'std': '', 'min': '', '25%': '', '50%': '', '75%': '', 'max': ''}}}, data={'rows': 10, 'columns': ['order_id', 'region', 'sales', 'quarter', 'rep'], 'numeric_stats': {'order_id': {'count': 10.0, 'unique': '', 'top': '', 'freq': '', 'mean': 105.5, 'std': 3.0276503540974917, 'min': 101.0, '25%': 103.25, '50%': 105.5, '75%': 107.75, 'max': 110.0}, 'region': {'count': 10, 'unique': 4, 'top': 'West', 'freq': 4, 'mean': '', 'std': '', 'min': '', '25%': '', '50%': '', '75%': '', 'max': ''}, 'sales': {'count': 10.0, 'unique': '', 'top': '', 'freq': '', 'mean': 1235.0, 'std': 536.4751210965477, 'min': 600.0, '25%': 825.0, '50%': 1175.0, '75%': 1450.0, 'max': 2200.0}, 'quarter': {'count': 10, 'unique': 4, 'top': 'Q1', 'freq': 3, 'mean': '', 'std': '', 'min': '', '25%': '', '50%': '', '75%': '', 'max': ''}, 'rep': {'count': 10, 'unique': 10, 'top': 'Alex', 'freq': 1, 'mean': '', 'std': '', 'min': '', '25%': '', '50%': '', '75%': '', 'max': ''}}}, is_error=False)
#
# Agent decided to use 'query'
# Result: CallToolResult(content=[TextContent(type='text', text='{"count":2,"rows":[{"order_id":107,"region":"West","sales":2000,"quarter":"Q3","rep":"Gale"},{"order_id":110,"region":"West","sales":2200,"quarter":"Q4","rep":"Jules"}]}', annotations=None, meta=None)], structured_content={'count': 2, 'rows': [{'order_id': 107, 'region': 'West', 'sales': 2000, 'quarter': 'Q3', 'rep': 'Gale'}, {'order_id': 110, 'region': 'West', 'sales': 2200, 'quarter': 'Q4', 'rep': 'Jules'}]}, data={'count': 2, 'rows': [{'order_id': 107, 'region': 'West', 'sales': 2000, 'quarter': 'Q3', 'rep': 'Gale'}, {'order_id': 110, 'region': 'West', 'sales': 2200, 'quarter': 'Q4', 'rep': 'Jules'}]}, is_error=False)

# %%
# create a connection to your MCP server
transport = PythonStdioTransport("mcp_server_fastmcp.py")

async with Client(transport) as client:
    await run_agent("Give me a summary of the dataset", client)
    await run_agent("Show West region sales > 1500", client)

# %% [markdown]
# ---
# ##  Architecture Recap
# ```
# +--------------------+      JSON-RPC (MCP)      +--------------------+
# |  Host / AI Agent   |  <-------------------->  | fastmcp MCP Server |
# | (LLM or Router)    |                        | (summarize, query)  |
# +--------------------+                         +--------------------+
# ```
# ---
