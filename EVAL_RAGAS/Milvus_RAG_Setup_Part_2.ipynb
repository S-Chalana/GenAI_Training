# %% [markdown]
# ##  RAG System Setup and Data Loading

# %% [markdown]
# # Create a collection

# %%
from pymilvus import connections, utility

# Connect to your running Milvus instance
connections.connect("default", host="127.0.0.1", port="19530")

# List all existing collections
print(utility.list_collections())
# Out:
# ['employee_policies', 'text_embedding_collection']

# %%
from pymilvus import Connections
from pymilvus import Collection
# Establish a connection to Milvus
Connections.connect(alias="default", host="localhost", port="19530")


# Access a specific collection by name
collection_name = "example_collection"
collection = Collection(collection_name)    
print(f"Collection '{collection_name}' accessed successfully.")
